# %% [markdown]
# ### Lematization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
lemmatizer.lemmatize("going", pos ='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("swimming", pos ='v'),lemmatizer.lemmatize("paying", pos ='v')
# Out:
# ('swim', 'pay')
