# %%
text = """The boys were playing happily in the beautiful garden while the girls were singing and dancing. They were enjoying the sunny weather and eating delicious apples because they had been studying very hard for their examinations. The teachers were encouraging the students to work carefully, think creatively, and solve problems efficiently."""

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
sentences=sent_tokenize(text)

# %%
from nltk.corpus import stopwords 
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\satya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\satya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
for i in range(len(sentences)):
    words=word_tokenize(sentences[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('The', 'DT'), ('boys', 'NNS'), ('playing', 'VBG'), ('happily', 'RB'), ('beautiful', 'JJ'), ('garden', 'NN'), ('girls', 'NNS'), ('singing', 'VBG'), ('dancing', 'NN'), ('.', '.')]
# [('They', 'PRP'), ('enjoying', 'VBG'), ('sunny', 'JJ'), ('weather', 'NN'), ('eating', 'VBG'), ('delicious', 'JJ'), ('apples', 'NNS'), ('studying', 'VBG'), ('hard', 'JJ'), ('examinations', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('teachers', 'NNS'), ('encouraging', 'JJ'), ('students', 'NNS'), ('work', 'VBP'), ('carefully', 'RB'), (',', ','), ('think', 'VBP'), ('creatively', 'RB'), (',', ','), ('solve', 'VB'), ('problems', 'NNS'), ('efficiently', 'RB'), ('.', '.')]

# %%
"hello!, i'ám Muskan Maurya . an artificial intellegence engineering student".split()
# Out:
# ['hello!,',
#  "i'ám",
#  'Muskan',
#  'Maurya',
#  '.',
#  'an',
#  'artificial',
#  'intellegence',
#  'engineering',
#  'student']

# %%
print(nltk.pos_tag("hello!, my name is Muskan Maurya . an artificial intellegence engineering student".split()))
# Out:
# [('hello!,', 'NN'), ('my', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Muskan', 'NNP'), ('Maurya', 'NNP'), ('.', '.'), ('an', 'DT'), ('artificial', 'JJ'), ('intellegence', 'NN'), ('engineering', 'NN'), ('student', 'NN')]
