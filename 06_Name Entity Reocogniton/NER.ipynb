# %%
text="Elon Musk, the CEO of Tesla and SpaceX, attended a technology conference in San Francisco on 10 October 2025. During the event, he discussed the future of artificial intelligence and space exploration. Representatives from Microsoft, Google, and NASA also participated in the conference. Thousands of visitors from Canada, Germany, and India attended the event to learn about the latest technological innovations."

# %%
import nltk
words=nltk.word_tokenize(text)
print(words)
# Out:
# ['Elon', 'Musk', ',', 'the', 'CEO', 'of', 'Tesla', 'and', 'SpaceX', ',', 'attended', 'a', 'technology', 'conference', 'in', 'San', 'Francisco', 'on', '10', 'October', '2025', '.', 'During', 'the', 'event', ',', 'he', 'discussed', 'the', 'future', 'of', 'artificial', 'intelligence', 'and', 'space', 'exploration', '.', 'Representatives', 'from', 'Microsoft', ',', 'Google', ',', 'and', 'NASA', 'also', 'participated', 'in', 'the', 'conference', '.', 'Thousands', 'of', 'visitors', 'from', 'Canada', ',', 'Germany', ',', 'and', 'India', 'attended', 'the', 'event', 'to', 'learn', 'about', 'the', 'latest', 'technological', 'innovations', '.']

# %%
tags = nltk.pos_tag (words)

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\satya\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\satya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
# !pip install svgling
# Out:
# ...
#
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    -------------------- ------------------- 1/2 [svgling]
#    -------------------- ------------------- 1/2 [svgling]
#    ---------------------------------------- 2/2 [svgling]
#
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nltk.ne_chunk(tags)
# Out:
# Tree('S', [Tree('PERSON', [('Elon', 'NNP')]), Tree('GPE', [('Musk', 'NNP')]), (',', ','), ('the', 'DT'), Tree('ORGANIZATION', [('CEO', 'NNP')]), ('of', 'IN'), Tree('GPE', [('Tesla', 'NNP')]), ('and', 'CC'), Tree('ORGANIZATION', [('SpaceX', 'NNP')]), (',', ','), ('attended', 'VBD'), ('a', 'DT'), ('technology', 'NN'), ('conference', 'NN'), ('in', 'IN'), Tree('GPE', [('San', 'NNP'), ('Francisco', 'NNP')]), ('on', 'IN'), ('10', 'CD'), ('October', 'NNP'), ('2025', 'CD'), ('.', '.'), ('During', 'IN'), ('the', 'DT'), ('event', 'NN'), (',', ','), ('he', 'PRP'), ('discussed', 'VBD'), ('the', 'DT'), ('future', 'NN'), ('of', 'IN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('and', 'CC'), ('space', 'NN'), ('exploration', 'NN'), ('.', '.'), ('Representatives', 'NNS'), ('from', 'IN'), Tree('GPE', [('Microsoft', 'NNP')]), (',', ','), Tree('GPE', [('Google', 'NNP')]), (',', ','), ('and', 'CC'), Tree('ORGANIZATION', [('NASA', 'NNP')]), ('also', 'RB'), ('participated', 'VBD'), ('in', 'IN'), ('the'
# ...
